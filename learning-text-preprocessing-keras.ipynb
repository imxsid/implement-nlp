# %% [markdown]
# <a href="https://www.kaggle.com/sid9300/learning-text-preprocessing-keras?scriptVersionId=82943130" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np

from tensorflow.keras.preprocessing.text import Tokenizer

# %% [markdown]
# ## Tokenization

# %%
# Tokenising sentences
sentences = [
    'The quick brown fox jumps over the lazy dog.'
]

tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'quick': 2,
#  'brown': 3,
#  'fox': 4,
#  'jumps': 5,
#  'over': 6,
#  'lazy': 7,
#  'dog': 8}

# %%
train_sequence = tokenizer.texts_to_sequences(sentences)
train_sequence = np.array(train_sequence)
print(train_sequence)
# Out:
# [[1 2 3 4 5 6 1 7 8]]
